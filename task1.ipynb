# %%
# OASIS INFOBYTE internship task 1
#EXPLORATORY DATA ANALYSIS ON RETAIL SALES DATA

#1. DATA LOADING AND CLEANING
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df=pd.read_csv('retail_sales_dataset.csv')
df['Data']=pd.to_datetime(df['Date'])
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount       Data
# 0         3              50           150 2023-11-24
# 1         2             500          1000 2023-02-27
# 2         1              30            30 2023-01-13
# 3         1             500           500 2023-05-21
# 4         2              50           100 2023-05-06

# %%
#2.DESCRIPTIVE STATISTICS 
df[['Age','Quantity','Price per Unit','Total Amount']].describe()
# Out:
#               Age     Quantity  Price per Unit  Total Amount
# count  1000.00000  1000.000000     1000.000000   1000.000000
# mean     41.39200     2.514000      179.890000    456.000000
# std      13.68143     1.132734      189.681356    559.997632
# min      18.00000     1.000000       25.000000     25.000000
# 25%      29.00000     1.000000       30.000000     60.000000
# 50%      42.00000     3.000000       50.000000    135.000000
# 75%      53.00000     4.000000      300.000000    900.000000
# max      64.00000     4.000000      500.000000   2000.000000

# %%
#3.TIME SERIES ANALYSIS
daily_sales=df.groupby('Date')['Total Amount'].sum()
plt.figure()
daily_sales.plot()
plt.title('Daily sales Over the Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()

# %%
#4. PRODUCT CATEGORY ANALYSIS
category_sales=df.groupby('Product Category')['Total Amount'].sum()
plt.figure()
category_sales.plot(kind='bar')
plt.title('sales by product category')
plt.xlabel('category')
plt.ylabel('total sales')
plt.show()

# %%
#5. CORRELATION HEATMAP

numeric_df=df[['Age','Quantity','Price per Unit','Total Amount']]
corr = numeric_df.corr()
plt.figure()
plt.imshow(corr)
plt.xticks(range(len(corr.columns)),corr.columns,rotation=45)
plt.yticks(range(len(corr.columns)),corr.columns)
plt.colorbar()

for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        plt.text(j,i,round(corr.iloc[i,j],2), ha='center',va='center')
plt.title('correlation heatmap')
plt.show()

# %%
#6. CONCLUSINONS
ELECTRONICS AND CLOTHING GENERATES HIGHEST SALES
TOTAL AMOUNT STRONGLY DEPENDS ON PRICE PER UNIT AND QUANTITY OF THE PRODUCT
